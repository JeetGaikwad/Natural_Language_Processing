# %%
import cv2
import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, LeakyReLU
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('images.png')
img = cv2.resize(img, (500,500))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
model.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', input_shape=(500,500,3)))
# model.add(LeakyReLU(alpha=0.01))
model.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu',))
# model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
model.add(Conv2D(128, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(128, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
model.add(Conv2D(256, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(256, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(256, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
model.add(Conv2D(512, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(512, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(512, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
model.add(Conv2D(512, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(512, kernel_size=(3,3), padding='same', activation='relu'))
model.add(Conv2D(512, kernel_size=(3,3), padding='same', activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# %%
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dense(4096, activation='relu'))
model.add(Dense(1, activation='softmax'))

# %%
model.build()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_26 (Conv2D)          (None, 500, 500, 64)      1792
#
#  conv2d_27 (Conv2D)          (None, 500, 500, 64)      36928
#
#  max_pooling2d_10 (MaxPooli  (None, 250, 250, 64)      0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 250, 250, 128)     73856
#
#  conv2d_29 (Conv2D)          (None, 250, 250, 128)     147584
#
#  max_pooling2d_11 (MaxPooli  (None, 125, 125, 128)     0
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 125, 125, 256)     295168
#
#  conv2d_31 (Conv2D)          (None, 125, 125, 256)     590080
#
#  conv2d_32 (Conv2D)          (None, 125, 125, 256)     590080
#
#  max_pooling2d_12 (MaxPooli  (None, 62, 62, 256)       0
#  ng2D)
#
#  conv2d_33 (Conv2D)          (None, 62, 62, 512)       1180160
#
#  conv2d_34 (Conv2D)          (None, 62, 62, 512)       2359808
#
# ...

# %%
result = model.predict(np.array([img]))

for i in range(512):
  feature_img = result[0,:,:,i]
  ax = plt.subplot(32,32,i+1)
  ax.set_xticks([])
  ax.set_yticks([])
  plt.imshow(feature_img, cmap="gray")
plt.show()
# Out:
# 1/1 [==============================] - 3s 3s/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-914fa5a5f59a> in <cell line: 3>()
#       2
#       3 for i in range(512):
# ----> 4   feature_img = result[0,:,:,i]
#       5   ax = plt.subplot(32,32,i+1)
#       6   ax.set_xticks([])
#
# IndexError: too many indices for array: array is 2-dimensional, but 4 were indexed

# %%
result2 = model.predict(np.array([img]))
print(result2)
# Out:
# 1/1 [==============================] - 4s 4s/step
# [[1.]]

# %%
print(result)
# Out:
# [[1.]]
